# %% [markdown]
# ## 1. UNDERSTANDING THE GIVEN TASK
# #### Task Given by instructor Krish Naik
# * Solve in ipynb:
# 1. Import the dataset.
# https://archive.ics.uci.edu/ml/datasets/Algerian+Forest+Fires+Dataset++#
# 2. Do proper EDA(analysis) of your dataset and create a report
# 3. Then perform necessary preprocessing steps

# %% [markdown]
# ## 2. DATA COLLECTION AND UNDERSTANDING
#
# * I used a dataset on **Algerian Forest Fires** from UCI. The dataset contains a culmination of forest fire observations and data in two regions of Algeria: the Bejaia region and the Sidi Bel-Abbes region. The timeline of this dataset is from **June 2012 to September 2012**. In this project, we focused on whether certain weather features could predict forest fires in these regions using few Classification algorithms.
#
#
# * As per the Task given i choose regression problem to predict fire weather index

# %% [markdown]
# ## 3. DATA EXPLORATION
#
# * In this step, we will apply Exploratory Data Analysis (EDA) to extract insights from the data set to know which features have contributed more in predicting Forest fire by performing Data Analysis using Pandas and Data visualization using Matplotlib & Seaborn. It is always a good practice to understand the data first and try to gather as many insights from it.
#
#
# Below are tasks to be performed in EDA:
#
# **1. Importing Libraries**
#
#
# **2. Data Cleaning for EDA Report**
#
# **3. Exploratory Data Analysis (EDA) on all Features**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline 
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Algerian_forest_fires_dataset.csv',header=1)
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df[df['month'].isnull()]
# Out:
#                                day month year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN  NaN         NaN  NaN  NaN   NaN
#
#     FFMC  DMC   DC  ISI  BUI  FWI Classes
# 122  NaN  NaN  NaN  NaN  NaN  NaN       NaN

# %%
df[df['year'].isnull()]
# Out:
#                                day month year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN  NaN         NaN  NaN  NaN   NaN
#
#     FFMC  DMC   DC  ISI  BUI  FWI Classes
# 122  NaN  NaN  NaN  NaN  NaN  NaN       NaN

# %%
df['month'].unique()
# Out:
# array(['06', '07', '08', '09', nan, 'month'], dtype=object)

# %%
df.shape
# Out:
# (246, 14)

# %%
## Columns which has null values
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %% [markdown]
# The dataset is converted into two sets based on Region from 122th index,
# we can make a new column based on the Region
#
#  **1 : "Bejaia Region Dataset"**
#
#  **2 : "Sidi-Bel Abbes Region Dataset"**

# %%
df.loc[:122,'Region']=1
df.loc[122:,'Region']=2
df[['Region']] = df[['Region']].astype(int)

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
df = df.dropna().reset_index(drop=True)

# %%
df.shape
# Out:
# (244, 15)

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         2

# %%
df.iloc[[167]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC   DMC    DC  ISI   BUI  \
# 167  16    07  2012          31  83  17     0  84.5  19.4  33.1  4.7  19.2
#
#      FWI Classes    Region
# 167  7.3   fire          2

# %% [markdown]
# ## Insights
# - The rows which had NaN values are removed

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Insights
# - There are no duplicate values present in dataset

# %%
# Checking data type 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4    RH          244 non-null    object
#  5    Ws          244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       244 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 27.8+ KB

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
# Removing the unnecessary spacing between columns 
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df = df.drop(122).reset_index(drop=True)

# %%
df.shape
# Out:
# (243, 15)

# %%
# Changing the required columns as integer data type
df[['month','day','year','Temperature','RH','Ws']] = df[['month','day','year','Temperature','RH','Ws']].astype(int)

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4    5      6  2012           27  77  16     0  64.8    3  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          1
# 1  0.4  not fire          1
# 2  0.1  not fire          1
# 3    0  not fire          1
# 4  0.5  not fire          1

# %%
df[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']] = df[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']].astype(float)

# %%
df.dtypes
# Out:
# day              int32
# month            int32
# year             int32
# Temperature      int32
# RH               int32
# Ws               int32
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes         object
# Region           int32
# dtype: object

# %%
# Checking the value counts
df.Classes.value_counts()
# Out:
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %% [markdown]
# # Insights
# - Looks like the values are misplaced

# %%
## Strip misplaced values
df.Classes = df.Classes.str.strip()

# %%
df.Classes.value_counts()
# Out:
# fire        137
# not fire    106
# Name: Classes, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
one_hot_encoder = OneHotEncoder()

# %%
one_hot_encoder
# Out:
# OneHotEncoder()

# %%
one_hot_encoder.fit_transform(df[['Classes']])
# Out:
# <243x2 sparse matrix of type '<class 'numpy.float64'>'
# 	with 243 stored elements in Compressed Sparse Row format>

# %%
one_hot_encoded = one_hot_encoder.fit_transform(df[['Classes']]).toarray()

# %%
Classes_encoded = pd.DataFrame(one_hot_encoded,columns=one_hot_encoder.get_feature_names_out())

# %%
Classes_encoded
# Out:
#      Classes_fire  Classes_not fire
# 0             0.0               1.0
# 1             0.0               1.0
# 2             0.0               1.0
# 3             0.0               1.0
# 4             0.0               1.0
# ..            ...               ...
# 238           1.0               0.0
# 239           0.0               1.0
# 240           0.0               1.0
# 241           0.0               1.0
# 242           0.0               1.0
#
# [243 rows x 2 columns]

# %%
df[['encoded_classes_fire','encoded_classes_not_fire']] = Classes_encoded

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  Region  encoded_classes_fire  encoded_classes_not_fire
# 0  0.5  not fire       1                   0.0                       1.0
# 1  0.4  not fire       1                   0.0                       1.0
# 2  0.1  not fire       1                   0.0                       1.0
# 3  0.0  not fire       1                   0.0                       1.0
# 4  0.5  not fire       1                   0.0                       1.0

# %%
df[['encoded_classes_fire','encoded_classes_not_fire']].value_countscounts()
# Out:
# encoded_classes_fire  encoded_classes_not_fire
# 1.0                   0.0                         137
# 0.0                   1.0                         106
# dtype: int64

# %%
df = df.drop(columns=['Classes'])

# %%
df[['encoded_classes_fire','encoded_classes_not_fire']] = df[['encoded_classes_fire','encoded_classes_not_fire']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   day                       243 non-null    int32
#  1   month                     243 non-null    int32
#  2   year                      243 non-null    int32
#  3   Temperature               243 non-null    int32
#  4   RH                        243 non-null    int32
#  5   Ws                        243 non-null    int32
#  6   Rain                      243 non-null    float64
#  7   FFMC                      243 non-null    float64
#  8   DMC                       243 non-null    float64
#  9   DC                        243 non-null    float64
#  10  ISI                       243 non-null    float64
#  11  BUI                       243 non-null    float64
#  12  FWI                       243 non-null    float64
# ...

# %% [markdown]
# ## Region 1 - Begaia Region

# %%
df[:122]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1      2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2      3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4      5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...  ...   ...  ...  ...
# 117   26      9  2012           31  54  11   0.0  82.0  6.0  16.3  2.5  6.2
# 118   27      9  2012           31  66  11   0.0  85.7  8.3  24.9  4.0  9.0
# 119   28      9  2012           32  47  14   0.7  77.5  7.1   8.8  1.8  6.8
# 120   29      9  2012           26  80  16   1.8  47.4  2.9   7.7  0.3  3.0
# 121   30      9  2012           25  78  14   1.4  45.0  1.9   7.5  0.2  2.4
#
# ...

# %% [markdown]
# # Region 2 - Sidi-Bel Abbes Region

# %%
df[122:]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 122    1      6  2012           32  71  12   0.7  57.1   2.5   8.2  0.6   2.8
# 123    2      6  2012           30  73  13   4.0  55.7   2.7   7.8  0.6   2.9
# 124    3      6  2012           29  80  14   2.0  48.7   2.2   7.6  0.3   2.6
# 125    4      6  2012           30  64  14   0.0  79.4   5.2  15.4  2.2   5.6
# 126    5      6  2012           32  60  14   0.2  77.1   6.0  17.6  1.8   6.5
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
# ...

# %%
# Drop columns day,month and year
df.drop(['day','month','year'],axis=1,inplace=True)

# %%
df.drop(['encoded_classes_not_fire'],axis=1,inplace=True)

# %%
# PLot density plot for all features
plt.style.use('seaborn')
df.hist(bins=50, figsize=(20,15), ec = 'b')
plt.show()
# ec parameter specifies the color of the edges of the bars in the histogram.

# %%
sns.pairplot(data=df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Insights
# - The features are not highly correlated with each other

# %%
df.columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'Region', 'encoded_classes_fire'],
#       dtype='object')

# %%
plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='Temperature',kde=True,hue='Region',bins=30)
plt.subplot(122)
sns.histplot(data=df,x='Rain',kde=True,hue='Region',bins=30)
# Out:
# <Axes: xlabel='Rain', ylabel='Count'>

# %% [markdown]
# ## Insights
# - In both the regions,the temperature is looking similar
# - In Region 1,there is more rainfall than Region 2

# %%
plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='Temperature',kde=True,hue='encoded_classes_fire',bins=30)
plt.subplot(122)
sns.histplot(data=df,x='Rain',kde=True,hue='encoded_classes_fire',bins=30)
# Out:
# <Axes: xlabel='Rain', ylabel='Count'>

# %%
sns.boxplot(data=df,orient='h')
# Out:
# <Axes: >

# %% [markdown]
# ## Insights
# - There are greater no.of outliers in DC column

# %%
sns.scatterplot(data=df,x=df.Temperature,y=df.Rain,hue=df.Region)
# Out:
# <Axes: xlabel='Temperature', ylabel='Rain'>

# %% [markdown]
# ## Insights
# - Highest Rainfall occurs in between 27.5-30 Temperature in Region 1
