# %% [markdown]
# <a href="https://colab.research.google.com/github/data-en/Regular_classes_work/blob/main/Bokeh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bokeh

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure,output_file,show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')
p = figure(title ='test flower')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label='petal width'
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="66aed05d-1eb0-44b7-967e-6db1f3ff6fba" data-root-id="1146"></div>

# %%
output_file('test.html')
p = figure(title ='test flower')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label='petal width'
p.line(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="4dec7317-2f05-4f45-b1d6-7aabfe4f193a" data-root-id="1366"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file('line.html')
p = figure(title='line graph')
p.xaxis.axis_label = 'X-axis'
p.yaxis.axis_label = 'Y-axis'
p.line(x,y)
show(p)
# Out:
#   <div class="bk-root" id="32a9c047-b8ff-4ff4-9edc-7e0888c2b1f2" data-root-id="1035"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file('line.html')
p = figure(title='line graph')
p.scatter(x,y,size=5,fill_color='red',legend_label='This is my data point')
show(p)
# Out:
#   <div class="bk-root" id="de293ba3-c61b-47e3-856c-359f53c60fcd" data-root-id="2716"></div>
